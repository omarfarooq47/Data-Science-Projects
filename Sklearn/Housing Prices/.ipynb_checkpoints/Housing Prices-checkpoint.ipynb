# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from scipy.stats import norm
from sklearn.preprocessing import StandardScaler
from scipy import stats
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline

# %%
data = pd.read_csv('train.csv')
data.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
#converting to rupee
data['SalePrice'] = data['SalePrice']*162.46
data.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition   SalePrice
# ...

# %%
cols = data.columns
cols
# Out:
# Index(['Id', 'MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'Street',
#        'Alley', 'LotShape', 'LandContour', 'Utilities', 'LotConfig',
#        'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType',
#        'HouseStyle', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd',
#        'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType',
#        'MasVnrArea', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual',
#        'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1',
#        'BsmtFinType2', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating',
#        'HeatingQC', 'CentralAir', 'Electrical', '1stFlrSF', '2ndFlrSF',
#        'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath',
#        'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual',
#        'TotRmsAbvGrd', 'Functional', 'Fireplaces', 'FireplaceQu', 'GarageType',
#        'GarageYrBlt', 'GarageFinish', 'GarageCars', 'GarageArea', 'GarageQual',
# ...

# %% [markdown]
# # Data Exploration

# %%
#histogram
sns.distplot(data['SalePrice']);

# %%
print("Percentage higer than PKR 80,000,000",(data[data['SalePrice'] > 80000000].count())['SalePrice']/data['SalePrice'].count()*100, '%')
# Out:
# Percentage higer than PKR 80,000,000 0.6164383561643836 %

# %%
a = data.isnull().sum()
b = a.sort_values(ascending=False)
b.head(20)
# Out:
# PoolQC          1453
# MiscFeature     1406
# Alley           1369
# Fence           1179
# FireplaceQu      690
# LotFrontage      259
# GarageCond        81
# GarageType        81
# GarageYrBlt       81
# GarageFinish      81
# GarageQual        81
# BsmtExposure      38
# BsmtFinType2      38
# BsmtFinType1      37
# BsmtCond          37
# BsmtQual          37
# MasVnrArea         8
# MasVnrType         8
# Electrical         1
# Utilities          0
# dtype: int64

# %%
data = data.drop(columns=['Id', 'PoolQC', 'MiscFeature', 'Alley', 'Fence', 'FireplaceQu', 'LotFrontage'])

# %%
data.shape
# Out:
# (1460, 74)

# %%
a = data.isnull().sum()
b = a.sort_values(ascending=False)
b.head(20)
# Out:
# GarageType      81
# GarageYrBlt     81
# GarageFinish    81
# GarageQual      81
# GarageCond      81
# BsmtFinType2    38
# BsmtExposure    38
# BsmtFinType1    37
# BsmtCond        37
# BsmtQual        37
# MasVnrType       8
# MasVnrArea       8
# Electrical       1
# YearRemodAdd     0
# ExterQual        0
# ExterCond        0
# Exterior2nd      0
# Exterior1st      0
# Foundation       0
# BsmtFinSF1       0
# dtype: int64

# %%
col_list = [c for c in data.columns if data[c].dtype == 'object']
col_list
# Out:
# ['MSZoning',
#  'Street',
#  'LotShape',
#  'LandContour',
#  'Utilities',
#  'LotConfig',
#  'LandSlope',
#  'Neighborhood',
#  'Condition1',
#  'Condition2',
#  'BldgType',
#  'HouseStyle',
#  'RoofStyle',
#  'RoofMatl',
#  'Exterior1st',
#  'Exterior2nd',
#  'MasVnrType',
#  'ExterQual',
#  'ExterCond',
#  'Foundation',
#  'BsmtQual',
#  'BsmtCond',
#  'BsmtExposure',
#  'BsmtFinType1',
#  'BsmtFinType2',
#  'Heating',
#  'HeatingQC',
#  'CentralAir',
#  'Electrical',
#  'KitchenQual',
#  'Functional',
#  'GarageType',
#  'GarageFinish',
#  'GarageQual',
#  'GarageCond',
#  'PavedDrive',
#  'SaleType',
#  'SaleCondition']

# %%
cat_data = ['Id', 'MSSubClass', 'MSZoning', 'Street','Alley', 'LotShape', 'LandContour', 'Utilities', 'LotConfig',
            'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType','HouseStyle', 'OverallQual', 'OverallCond',
            'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType', 'ExterQual', 'ExterCond', 'Foundation', 
            'BsmtQual','BsmtCond', 'BsmtExposure', 'BsmtFinType2', 'Heating', 'HeatingQC', 'CentralAir', 'Electrical', 
            'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath', 'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual',
            'Functional', 'Fireplaces', 'FireplaceQu', 'GarageType','GarageFinish', 'GarageQual', 'GarageCond', 'PavedDrive', 
            'WoodDeckSF', 'OpenPorchSF','EnclosedPorch', '3SsnPorch', 'ScreenPorch', 'PoolQC','Fence', 'MiscFeature', 
            'MiscVal', 'SaleType','SaleCondition', 'BsmtFinType1']
len(cat_data)
# Out:
# 61

# %%
for c in cols:
    if c not in cat_data and c != 'SalePrice' and c != 'LotFrontage':
        plt.scatter(data[data[c].notnull()][c], data[data[c].notnull()]['SalePrice'])
        plt.title(c)
        plt.xlabel(c)
        plt.ylabel('SalePrice')
        plt.show()

# %%
for c in cols:
    if c not in cat_data and c != 'BsmtFinSF2' and c != 'LowQualFinSF' and c != 'PoolArea' and c != 'LotFrontage':
        sns.distplot(data[c], fit=norm);
        plt.title(c)
        plt.xlabel(c)
        plt.ylabel('Frequency Distribution')
        plt.show()

# %%
skewed = ['LotArea', '1stFlrSF', 'SalePrice' ]
for a in skewed:
    data[a] = np.log2(data[a])

# %%
for a in skewed:
    sns.distplot(data[c], fit=norm);
    plt.title(c)
    plt.xlabel(c)
    plt.ylabel('Frequency Distribution')
    plt.show()

# %% [markdown]
# # Missing Value Approximation

# %%
a = data.isnull().sum()
b = a.sort_values(ascending=False)
b.head(14)
# Out:
# GarageType      81
# GarageYrBlt     81
# GarageFinish    81
# GarageQual      81
# GarageCond      81
# BsmtFinType2    38
# BsmtExposure    38
# BsmtFinType1    37
# BsmtCond        37
# BsmtQual        37
# MasVnrType       8
# MasVnrArea       8
# Electrical       1
# YearRemodAdd     0
# dtype: int64

# %%
col_list = [c for c in data.columns if data[c].dtype == 'object']
col_list
# Out:
# ['MSZoning',
#  'Street',
#  'LotShape',
#  'LandContour',
#  'Utilities',
#  'LotConfig',
#  'LandSlope',
#  'Neighborhood',
#  'Condition1',
#  'Condition2',
#  'BldgType',
#  'HouseStyle',
#  'RoofStyle',
#  'RoofMatl',
#  'Exterior1st',
#  'Exterior2nd',
#  'MasVnrType',
#  'ExterQual',
#  'ExterCond',
#  'Foundation',
#  'BsmtQual',
#  'BsmtCond',
#  'BsmtExposure',
#  'BsmtFinType1',
#  'BsmtFinType2',
#  'Heating',
#  'HeatingQC',
#  'CentralAir',
#  'Electrical',
#  'KitchenQual',
#  'Functional',
#  'GarageType',
#  'GarageFinish',
#  'GarageQual',
#  'GarageCond',
#  'PavedDrive',
#  'SaleType',
#  'SaleCondition']

# %%
# Make a copy of data
train_data = data.copy()

# Change data types of columns
for c in col_list:
    train_data[c] = train_data[c].astype('category')
    train_data[c] = train_data[c].cat.codes

# %%
# Compare Actual and Encoded labels
for c in col_list:
    print('column:', c)
    print(data[c].unique().tolist())
    print(train_data[c].unique().tolist(), '\n')
# Out:
# column: MSZoning
# ['RL', 'RM', 'C (all)', 'FV', 'RH']
# [3, 4, 0, 1, 2]
#
# column: Street
# ['Pave', 'Grvl']
# [1, 0]
#
# column: LotShape
# ['Reg', 'IR1', 'IR2', 'IR3']
# [3, 0, 1, 2]
#
# column: LandContour
# ['Lvl', 'Bnk', 'Low', 'HLS']
# [3, 0, 2, 1]
#
# column: Utilities
# ['AllPub', 'NoSeWa']
# [0, 1]
#
# column: LotConfig
# ['Inside', 'FR2', 'Corner', 'CulDSac', 'FR3']
# [4, 2, 0, 1, 3]
#
# column: LandSlope
# ['Gtl', 'Mod', 'Sev']
# [0, 1, 2]
#
# column: Neighborhood
# ['CollgCr', 'Veenker', 'Crawfor', 'NoRidge', 'Mitchel', 'Somerst', 'NWAmes', 'OldTown', 'BrkSide', 'Sawyer', 'NridgHt', 'NAmes', 'SawyerW', 'IDOTRR', 'MeadowV', 'Edwards', 'Timber', 'Gilbert', 'StoneBr', 'ClearCr', 'NPkVill', 'Blmngtn', 'BrDale', 'SWISU', 'Blueste']
# [5, 24, 6, 15, 11, 21, 14, 17, 3, 19, 16, 12, 20, 9, 10, 7, 23, 8, 22, 4, 13, 0, 2, 18, 1]
#
# column: Condition1
# ['Norm', 'Feedr', 'PosN', 'Artery', 'RRAe', 'RRNn', 'RRAn', 'PosA', 'RRNe']
# [2, 1, 4, 0, 5, 8, 6, 3, 7]
#
# column: Condition2
# ...

# %%
#take mode for missing vales of catagorical data

for c in ['Electrical', 'GarageType', 'GarageYrBlt', 'GarageFinish', 'GarageQual', 'GarageCond', 'BsmtFinType2', 
          'BsmtExposure', 'BsmtFinType1', 'BsmtCond', 'BsmtQual', 'MasVnrType']:
    missing_vals = train_data[c].isnull().sum()
    observed_vals = train_data.loc[train_data[c].notnull(), c]
    train_data.loc[train_data[c].isnull(), c] = observed_vals.mode()

# %%
#take median for missing vales of continuous data

for c in ['GarageYrBlt', 'MasVnrArea']:
    missing_vals = train_data[c].isnull().sum()
    observed_vals = train_data.loc[train_data[c].notnull(), c]
    train_data.loc[train_data[c].isnull(), c] = observed_vals.median()

# %%
a = train_data.isnull().sum()
b = a.sort_values(ascending=False)
b.head()
# Out:
# SalePrice      0
# RoofStyle      0
# Exterior1st    0
# Exterior2nd    0
# MasVnrType     0
# dtype: int64

# %%
# Correlation heatmap
corr = train_data.corr()
plt.figure(figsize=(12, 10))
sns.heatmap(corr[(corr >= 0.4) | (corr <= -0.4)],
cmap='viridis', vmax=1.0, vmin=-1.0, linewidths=0.1,
annot=True, annot_kws={"size": 8}, square=True)

# %% [markdown]
# # Model Training

# %%
# Standardize data
from sklearn.preprocessing import StandardScaler
# Columns not to be standardized. These are columns with categorical data,
# also we don't standardize our target vraiable
cat_data = ['Id', 'MSSubClass', 'MSZoning', 'Street','Alley', 'LotShape', 'LandContour', 'Utilities', 'LotConfig',
            'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType','HouseStyle', 'OverallQual', 'OverallCond',
            'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType', 'ExterQual', 'ExterCond', 'Foundation', 
            'BsmtQual','BsmtCond', 'BsmtExposure', 'BsmtFinType2', 'Heating', 'HeatingQC', 'CentralAir', 'Electrical', 
            'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath', 'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual',
            'Functional', 'Fireplaces', 'FireplaceQu', 'GarageType','GarageFinish', 'GarageQual', 'GarageCond', 'PavedDrive', 
            'WoodDeckSF', 'OpenPorchSF','EnclosedPorch', '3SsnPorch', 'ScreenPorch', 'PoolQC','Fence', 'MiscFeature', 
            'MiscVal', 'SaleType','SaleCondition', 'BsmtFinType1']
# Pick remaining columns and standardize them
columns = [c for c in train_data.columns if c not in cat_data]
scaler = StandardScaler()
scaler.fit(train_data[columns])
train_data[columns] = scaler.transform(train_data[columns])

# %%
# Train Test Split
from sklearn.model_selection import train_test_split
y = train_data['SalePrice']
X = train_data.drop(columns=['SalePrice'])
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)
print("Training Set Dimensions:", X_train.shape)
print("Validation Set Dimensions:", X_test.shape)
# Out:
# Training Set Dimensions: (1168, 73)
# Validation Set Dimensions: (292, 73)

# %%
train_data.head()
# Out:
#    MSSubClass  MSZoning   LotArea  Street  LotShape  LandContour  Utilities  \
# 0          60         3 -0.133231       1         3            3          0
# 1          20         3  0.113442       1         3            3          0
# 2          60         3  0.420061       1         0            3          0
# 3          70         3  0.103347       1         0            3          0
# 4          60         3  0.878409       1         0            3          0
#
#    LotConfig  LandSlope  Neighborhood  ...  EnclosedPorch  3SsnPorch  \
# 0          4          0             5  ...              0          0
# 1          2          0            24  ...              0          0
# 2          4          0             5  ...              0          0
# 3          0          0             6  ...            272          0
# 4          2          0            15  ...              0          0
#
#    ScreenPorch  PoolArea  MiscVal    MoSold    YrSold  SaleType  \
# ...

# %%
# Train Random Forest Regressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_error
randomf = RandomForestRegressor(n_estimators=200)
randomf.fit(X_train, y_train)
# Out:
# RandomForestRegressor(bootstrap=True, ccp_alpha=0.0, criterion='mse',
#                       max_depth=None, max_features='auto', max_leaf_nodes=None,
#                       max_samples=None, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=1,
#                       min_samples_split=2, min_weight_fraction_leaf=0.0,
#                       n_estimators=200, n_jobs=None, oob_score=False,
#                       random_state=None, verbose=0, warm_start=False)

# %%
# Measure mean absolute error for training and validation sets
print('Mean Absolute Error for Training Set:', mean_absolute_error(y_train, randomf.predict(X_train)))
print('Mean Absolute Error for Test Set:', mean_absolute_error(y_test, randomf.predict(X_test)))
# Out:
# Mean Absolute Error for Training Set: 0.08795758819603192
# Mean Absolute Error for Test Set: 0.2466812464804624

# %%
# important features for random forest regressor
for name, importance in zip(X.columns, randomf.feature_importances_):
    print('feature:', name, "=", importance)
importances = randomf.feature_importances_
indices = np.argsort(importances)
features = X.columns
plt.figure(figsize= (5, 15))
plt.title('Feature Importances')
plt.barh(range(len(indices)), importances[indices], color='b', align='center')
plt.yticks(range(len(indices)), [features[i] for i in indices])
plt.xlabel('Relative Importance')

plt.show()
# Out:
# feature: MSSubClass = 0.0021020431863857545
# feature: MSZoning = 0.00954077751914402
# feature: LotArea = 0.015940897174919647
# feature: Street = 7.103919145614465e-06
# feature: LotShape = 0.001024629419342829
# feature: LandContour = 0.001508452453698477
# feature: Utilities = 9.379448762474092e-08
# feature: LotConfig = 0.0007781167452817564
# feature: LandSlope = 0.0005044071019907755
# feature: Neighborhood = 0.004985794582506911
# feature: Condition1 = 0.000846461959957417
# feature: Condition2 = 0.00015737382693796958
# feature: BldgType = 0.0005457006250263212
# feature: HouseStyle = 0.0010835779003382851
# feature: OverallQual = 0.53637752314749
# feature: OverallCond = 0.011651094551345862
# feature: YearBuilt = 0.014527762147042439
# feature: YearRemodAdd = 0.008822893014846386
# feature: RoofStyle = 0.0006060118175082887
# feature: RoofMatl = 9.930227903590687e-05
# feature: Exterior1st = 0.002724143406233749
# feature: Exterior2nd = 0.0016793373988535907
# ...

# %%
from sklearn import linear_model
model = linear_model.LinearRegression()
model.fit(X_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
# Measure mean absolute error for training and validation sets
print('Mean Absolute Error for Training Set:', mean_absolute_error(y_train, model.predict(X_train)))
print('Mean Absolute Error for Test Set:', mean_absolute_error(y_test, model.predict(X_test)))
# Out:
# Mean Absolute Error for Training Set: 0.21140436645397376
# Mean Absolute Error for Test Set: 0.2478385081187205

# %% [markdown]
# # Hyperparameter tuning of Random Forest Regressor

# %%
from sklearn.model_selection import GridSearchCV
params = {'max_depth': [5, 10, 12, 18], 
          'max_features': [2, 4, 6], 
          'min_samples_leaf': [3, 4, 5], 
          'min_samples_split': [8, 10, 12],
          'n_estimators': [100, 200, 300]}
k = 5
score_param = 'neg_mean_absolute_error'
rf = RandomForestRegressor()
rf_grid = GridSearchCV(estimator=rf, param_grid=params, scoring=score_param, n_jobs=-1, cv=k, verbose=True)
rf_grid.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 324 candidates, totalling 1620 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  42 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=-1)]: Done 192 tasks      | elapsed:  1.6min
# [Parallel(n_jobs=-1)]: Done 442 tasks      | elapsed:  2.4min
# [Parallel(n_jobs=-1)]: Done 792 tasks      | elapsed:  3.7min
# [Parallel(n_jobs=-1)]: Done 1242 tasks      | elapsed:  5.3min
# [Parallel(n_jobs=-1)]: Done 1620 out of 1620 | elapsed:  6.6min finished
# GridSearchCV(cv=5, error_score=nan,
#              estimator=RandomForestRegressor(bootstrap=True, ccp_alpha=0.0,
#                                              criterion='mse', max_depth=None,
#                                              max_features='auto',
#                                              max_leaf_nodes=None,
#                                              max_samples=None,
# ...

# %%
from sklearn.metrics import mean_absolute_error

best_model = rf_grid.best_estimator_

predict_train = best_model.predict(X_train)
predict_test = best_model.predict(X_test)

print('Mean Absolute Error for Training Set:', mean_absolute_error(y_train, predict_train))
print('Mean Absolute Error for Validation Set:', mean_absolute_error(y_test, predict_test))
# Out:
# Mean Absolute Error for Training Set: 0.17147874975154376
# Mean Absolute Error for Validation Set: 0.2647020240671943

# %%
rf_grid.best_estimator_
# Out:
# RandomForestRegressor(bootstrap=True, ccp_alpha=0.0, criterion='mse',
#                       max_depth=18, max_features=6, max_leaf_nodes=None,
#                       max_samples=None, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=3,
#                       min_samples_split=10, min_weight_fraction_leaf=0.0,
#                       n_estimators=300, n_jobs=None, oob_score=False,
#                       random_state=None, verbose=0, warm_start=False)
